# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
n = 5; print((1+1/n)**n)
def f(n): return (1-1/n)**n
ns = np.array([i for i in range(1,1000)])
plt.plot(ns, f(ns))
# Out:
# 2.4883199999999994

# %%
f(1000)
# Out:
# 0.36769542477096373

# %%
1/np.e
# Out:
# 0.36787944117144233
